# %%
dataset = [60, 20, 40, 30, 50, 10]
dataset.sort()
print(dataset)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
dataset = [60, 20, 40, 30, 50, 10]
sorted_dataset = sorted(dataset)
print(dataset)
print(sorted_dataset)
# Out:
# [60, 20, 40, 30, 50, 10]
# [10, 20, 30, 40, 50, 60]
