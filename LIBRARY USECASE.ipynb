# %%
w = [1, 2, 5, 6]
x = [2, 4, 5, 3]
f = 0
for i in range(4):
  f = f + w[i] * x[i]
print(f)
# Out:
# 53

# %%
import numpy as np
w = np.array([1, 2, 5, 6])
x = np.array([2, 4, 5, 3])
f = np.dot(w,x)
print(f)
# Out:
# 53
