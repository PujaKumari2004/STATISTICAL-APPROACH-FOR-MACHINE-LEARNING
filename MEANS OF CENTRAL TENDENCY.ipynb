# %%
dataset = [20,67,70,56,90,45]

#FINDING MEAN

l = sorted(dataset)
print(l)
mean = sum(dataset) / len(dataset)
print("Mean:", mean)


#FINDING MEDIAN

if (len(l) % 2 == 0):
  median_index = len(l) / 2
  sum_median = l[int(len(l)/2)] + l[int(len(l)/2-1)]
  median = sum_median / 2
  print("Medain:",median)
else:
   median_index = len(l) / 2
   median_index_rounded = round(median_index)
   #print(median_index_rounded)
   median = l[median_index_rounded]
   print(median)

#FINDING MODE
max_count = 0
for i in range(0, len(l)):
  if (l.count(l[i]) > max_count):
    max_count = l.count(l[i])
    mode = l[i]
print("Mode:",mode)
# Out:
# [20, 45, 56, 67, 70, 90]
# Mean: 58.0
# Medain: 61.5
# Mode: 20

# %%
#FINDING MODE
dataset1 = [10,20,50,45,70]
a = sorted(dataset)
max_count = 0
if()
